# %%
# %pip install pandas
import pandas as pd
df = pd.read_csv(r"C:\Users\kesha\Downloads\foodguard-ai\foodguard-ai\ml\data\raw\food.csv")
print([c for c in df.columns if "protein" in c.lower() or "fiber" in c.lower()])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 df = pd.read_csv(r"C:\Users\kesha\Downloads\foodguard-ai\foodguard-ai\ml\data\raw\food.csv")
#       3 print([c for c in df.columns if "protein" in c.lower() or "fiber" in c.lower()])
#
# ModuleNotFoundError: No module named 'pandas'
